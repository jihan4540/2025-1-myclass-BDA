# %% [markdown]
# <a href="https://colab.research.google.com/github/jihan4540/2025-1-myclass-BDA/blob/main/inclass/05w_B_wed_0402_easy_ch05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.DataFrame({'var1' : [4, 3, 8],
                   'var2' : [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1['var1'] + df1['var2']
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1["var_mean"] = (df1["var1"] + df1["var2"]) / 2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2 = df.copy()
df2

# %%
df2.sum()

# %%
df2.sum(axis=1)

# %%
df2["my_mean"] = df2[["var1","var2"]].mean(axis=1) # 시험 예상
df2

# %% [markdown]
# mpg  연비 변수

# %%
! git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 5.31 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
import pandas as pd # Import the pandas library and assign it the alias 'pd'

mpg = pd.read_csv('data/mpg.csv')
mpg.sample(8)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 141       nissan              altima    2.4  1999    4  manual(m5)   f   21
# 214   volkswagen               jetta    2.0  1999    4    auto(l4)   f   19
# 42         dodge         caravan 2wd    3.3  2008    6    auto(l4)   f   17
# 126         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
# 220   volkswagen               jetta    2.8  1999    6  manual(m5)   f   17
# 19     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11
# 110      hyundai              sonata    2.4  2008    4    auto(l4)   f   21
# 94          ford             mustang    4.6  1999    8    auto(l4)   r   15
#
#      hwy fl    category
# 141   29  r     compact
# 214   26  r     compact
# 42    24  r     minivan
# 126   12  e         suv
# 220   24  r     compact
# 19    15  e         suv
# 110   30  r     midsize
# 94    21  r  subcompact

# %%
mpg.cty + mpg.hwy
# Out:
# 0      47
# 1      50
# 2      51
# 3      51
# 4      42
#        ..
# 229    47
# 230    50
# 231    42
# 232    44
# 233    43
# Length: 234, dtype: int64

# %%
mpg.total = (mpg['cty'] + mpg['hwy']) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['total'] = (mpg['cty'] + mpg['hwy']) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['mpg_mean'] = mpg[['cty', 'hwy']].mean(axis='columns')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
mpg.total
# Out:
# 0      23.5
# 1      25.0
# 2      25.5
# 3      25.5
# 4      21.0
#        ...
# 229    23.5
# 230    25.0
# 231    21.0
# 232    22.0
# 233    21.5
# Name: total, Length: 234, dtype: float64

# %%
sum(mpg['total']) / len(mpg)
# Out:
# 20.14957264957265

# %%
mpg.total.mean()
# Out:
# np.float64(20.14957264957265)

# %% [markdown]
# ## 조건문 활용

# %%
mpg.total.describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg.total.plot.hist();

# %%
# !pip install koreanize-matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from koreanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 92.5 MB/s eta 0:00:00
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
import koreanize_matplotlib

# %%
# %config inlineBakcend.figure_format = 'retina'

# %%
mpg['total'].plot(kind="hist", title="히스토그램");

# %%
import seaborn as sns

sns.histplot(mpg, x="total");

# %%
import numpy as np

np.where(30 >=5, 'pass', 'fail')
# Out:
# array('pass', dtype='<U4')

# %%
np.where(30 <= 5, 'pass', 'fail')
# Out:
# array('fail', dtype='<U4')

# %%
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')
mpg.sample(10)
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 222   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 136      lincoln           navigator 2wd    5.4  2008    8    auto(l6)   r
# 199       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4
# 141       nissan                  altima    2.4  1999    4  manual(m5)   f
# 88          ford         f150 pickup 4wd    5.4  1999    8    auto(l4)   4
# 14          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 228   volkswagen                  passat    1.8  1999    4    auto(l5)   f
# 47         dodge             caravan 2wd    4.0  2008    6    auto(l6)   f
# 3           audi                      a4    2.0  2008    4    auto(av)   f
# 227   volkswagen                  passat    1.8  1999    4  manual(m5)   f
#
#      cty  hwy fl    category  total  mpg_mean  test
# 222   29   41  d  subcompact   35.0      35.0  pass
# 136   12   18  r         suv   15.0      15.0  fail
# 199   13   18  r         suv   15.5      15.5  fail
# 141   21   29  r     compact   25.0      25.0  pass
# 88    11   15  r      pickup   13.0      13.0  fail
# 14    15   25  p     compact   20.0      20.0  pass
# 228   18   29  p     midsize   23.5      23.5  pass
# 47    16   23  r     minivan   19.5      19.5  fail
# 3     21   30  p     compact   25.5      25.5  pass
# 227   21   29  p     midsize   25.0      25.0  pass

# %%
mpg['test'].value_counts()
# Out:
# test
# pass    128
# fail    106
# Name: count, dtype: int64

# %%
mpg['test'].value_counts().plot.bar();

# %%
sns.countplot(mpg, x="test");

# %%
sns.countplot(mpg, x="test", hue="test")
# Out:
# <Axes: xlabel='test', ylabel='count'>

# %%
sns.countplot(data=mpg, x="test", hue="test", stat= "percent");

# %%
sns.countplot(data=mpg, x="test", hue="cyl", stat= "percent");

# %%
sns.countplot(data=mpg, x="test", hue="category", stat= "percent");

# %%
np.where(mpg['total'] >= 30, 'A', np.where(mpg['total'] >= 20, 'B', 'C'))
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'C', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'B', 'C', 'B',
#        'B', 'C', 'C', 'C', 'C', 'C', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'C', 'C', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
#        'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
#        'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
#        'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'B',
#        'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'A', 'B', 'B', 'B', 'B',
#        'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
#        'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'A', 'A', 'A', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'B',
#        'B', 'B', 'B', 'B', 'A', 'B', 'B', 'B', 'B', 'B', 'B', 'C', 'B',
#        'A', 'A', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B'],
#       dtype='<U1')

# %%
mpg.grade = np.where(mpg['total'] >= 30, 'A',np.where(mpg['total'] >= 20, 'B', 'C'))
mpg.sample(5)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 29     chevrolet     k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4   11
# 146       nissan              altima    3.5  2008    6    auto(av)   f   19
# 27     chevrolet            corvette    7.0  2008    8  manual(m6)   r   15
# 36     chevrolet              malibu    3.6  2008    6    auto(s6)   f   17
# 127         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4   14
#
#      hwy fl category  total  mpg_mean  test grade
# 29    14  e      suv   12.5      12.5  fail     C
# 146   26  p  midsize   22.5      22.5  pass     B
# 27    24  p  2seater   19.5      19.5  fail     C
# 36    26  r  midsize   21.5      21.5  pass     B
# 127   19  r      suv   16.5      16.5  fail     C

# %%
n_grade = mpg['grade'].value_counts()
n_grade
# Out:
# grade
# B    118
# C    106
# A     10
# Name: count, dtype: int64

# %%
n_grade.plot.bar(rot=0)
# Out:
# <Axes: xlabel='grade'>

# %%
sns.countplot(mpg, x="test");

# %%
sns.countplot(mpg, x="grade", hue="grade", stat= "percent");

# %%
mpg['grade'].value_counts().index
# Out:
# Index(['B', 'C', 'A'], dtype='object', name='grade')

# %%
mpg['grade'].value_counts().sort_index().index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='grade')

# %%
sns.countplot(mpg, x="grade", hue="grade", stat= "percent", order=mpg['grade'].value_counts().sort_index().index);

# %%
sns.countplot(mpg, x="grade", hue="grade", stat= "percent", order=['A', 'B', 'C']);

# %%
mpg.grade.unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
np.sort(mpg.grade.unique())
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
sns.countplot(mpg, x="grade", hue="grade", stat= "percent", order=np.sort(mpg.grade.unique()));

# %% [markdown]
# ## 메소드 체이닝

# %%
mpg.grade.value_counts().sort_index()
# Out:
# grade
# A     10
# B    118
# C    106
# Name: count, dtype: int64

# %%
s = mpg['grade'].value_counts().sort_index()
s
# Out:
# grade
# A     10
# B    118
# C    106
# Name: count, dtype: int64

# %%
mpg['grade'].value_counts().sort_values(ascending=False)
# Out:
# grade
# B    118
# C    106
# A     10
# Name: count, dtype: int64

# %%
mpg['grade2']= np.where(mpg['total'] >= 30, 'A',
            np.where(mpg['total'] >= 25, 'B',
            np.where(mpg['total'] >= 20, 'C', 'D')))
mpg.sample(5)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 62         dodge         durango 4wd    5.7  2008    8    auto(l5)   4   13
# 88          ford     f150 pickup 4wd    5.4  1999    8    auto(l4)   4   11
# 126         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
# 189       toyota        camry solara    2.4  2008    4    auto(s5)   f   22
# 181       toyota               camry    2.4  2008    4  manual(m5)   f   21
#
#      hwy fl category  total  mpg_mean  test grade grade2
# 62    18  r      suv   15.5      15.5  fail     C      D
# 88    15  r   pickup   13.0      13.0  fail     C      D
# 126   12  e      suv   10.5      10.5  fail     C      D
# 189   31  r  compact   26.5      26.5  pass     B      B
# 181   31  r  midsize   26.0      26.0  pass     B      B

# %% [markdown]
# ## 연산자 OR 메소드 isin

# %%
mpg['size'] = np.where((mpg.category == 'compact') |
                       (mpg.category == 'subcompact') |
                       (mpg.category == '2seater'), 'small', 'large')

# %%
np.where((mpg.category == 'compact') |
         (mpg.category == 'subcompact') |
         (mpg.category == '2seater'), 'small', 'large')
# Out:
# array(['small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'small', 'small', 'small', 'small', 'small',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'small', 'small', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'large', 'large',
#        'large', 'large', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'large', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large', 'large', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'small', 'small', 'small', 'small',
#        'small', 'small', 'small', 'large', 'large', 'large', 'large',
#        'large', 'large', 'large'], dtype='<U5')

# %%
mpg['size'] = np.where((mpg.category == 'compact') |
                       (mpg.category == 'subcompact') |
                       (mpg.category == '2seater'), 'small', 'large')
mpg.sample(3)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 203       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4   15
# 117      hyundai            tiburon    2.0  2008    4  manual(m5)   f   20
# 118      hyundai            tiburon    2.0  2008    4    auto(l4)   f   20
#
#      hwy fl    category  total  mpg_mean  test grade grade2   size
# 203   17  r      pickup   16.0      16.0  fail     C      D  large
# 117   28  r  subcompact   24.0      24.0  pass     B      C  small
# 118   27  r  subcompact   23.5      23.5  pass     B      C  small

# %%
mpg['size'].value_counts()
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %%
mpg['size'] = np.where(mpg['category'].isin(['compact', 'subcompact', '2seater']), 'small', 'large')

mpg['size'].value_counts()
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %% [markdown]
# ## 정리하기

# %%
## 1. 패키지 로드
import pandas as pd
import numpy as np

## 2. 데이터 불러오기
mpg = pd.read_csv('data/mpg.csv')

## 3. 데이터 입력하기
mpg.shape       #행, 열 수
mpg.head()      # 데이터 앞부분
mpg.tail()      # 데이터 뒷부분
mpg.info()      # 속성
mpg.describe()  # 요약 통계량

## 4. 변수명 바꾸기
mpg = mpg.rename(columns = {'manufacturer' : 'company'})

# 5. 파생변수 만들기
mpg['total'] = (mpg['cty'] + mpg['hwy'])/2                  # 변수 조합
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')  # 조건문 활용

# 6. 빈도 확인하기
count_test = mpg['test'].value_counts()  # 빈도표 만들기
count_test.plot.bar(rot = 0)             # 빈도 막대 그래프 만들기

# %% [markdown]
# ## 단원 06

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')
exam.sample(4)
# Out:
#     id  nclass  math  english  science
# 18  19       5    89       68       87
# 13  14       4    48       87       12
# 9   10       3    50       98       45
# 14  15       4    75       56       78

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes

# %%
exam.query('nclass == 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass == 2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('nclass != 2')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam['nclass'] == 2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: nclass, dtype: bool

# %%
exam[exam['nclass'] == 2]
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('math > 50')
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('english >= 80')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1 & math >= 50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam[(exam.nclass == 1) & (exam.math >= 50)]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('english < 90 | science < 50')
# Out:
#     id  nclass  math  english  science
# 2    3       1    45       86       78
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1 | nclass == 3 | nclass == 5')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
3 in [1, 2, 3, 4]
# Out:
# True

# %%
exam.query('nclass in [1, 3, 5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam.nclass.isin([1, 3, 5])]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
nclass1 = exam.query('nclass == 1')

nclass1
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
nclass2 = exam.query('nclass == 2')

nclass2
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
nclass1['math'].mean()
# Out:
# np.float64(46.25)

# %%
nclass2.english.mean()
# Out:
# np.float64(84.25)

# %%
nclass2['english'].mean()
# Out:
# np.float64(84.25)

# %%
df = pd.DataFrame({'sex'     : ['F', 'M', 'F', 'M'],
                   'country' : ['Korea', 'China', 'Japan', 'USA']})
df
# Out:
#   sex country
# 0   F   Korea
# 1   M   China
# 2   F   Japan
# 3   M     USA

# %%
df.query('sex == "F" & country == "Korea"')
# Out:
#   sex country
# 0   F   Korea

# %%
df.query("sex == 'F' & country == 'Korea'")
# Out:
#   sex country
# 0   F   Korea

# %%
var = 3
exam.query('nclass == @var') # 변수 @ 필요
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
var = 3
exam.query(f'nclass == {var}')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %% [markdown]
# ## df isin()

# %%
df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]},
                 index=['falcon', 'dog'])
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog         True       True

# %%
 ~df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon      True       True
# dog        False      False

# %%
exam.columns
# Out:
# Index(['id', 'nclass', 'math', 'english', 'science'], dtype='object')

# %%
exam.columns[1]
# Out:
# 'nclass'

# %%
exam.columns[2]
# Out:
# 'math'

# %%
exam[exam.columns[2]]
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[exam.columns[1:3]]
# Out:
#     nclass  math
# 0        1    50
# 1        1    60
# 2        1    45
# 3        1    30
# 4        2    25
# 5        2    50
# 6        2    80
# 7        2    90
# 8        3    20
# 9        3    50
# 10       3    65
# 11       3    45
# 12       4    46
# 13       4    48
# 14       4    75
# 15       4    58
# 16       5    65
# 17       5    80
# 18       5    89
# 19       5    78

# %% [markdown]
# ## df drop

# %%
exam.drop(columns=["math", 'english'])
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam.drop(2)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop([2, 4, 6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index =[2, 4, 6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=[2, 4, 6], axis=0)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=["math", "english"], axis=1) # axis = 1로 꼭
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass == 1')['math']
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# Name: math, dtype: int64

# %%
exam.query('nclass == 1')[['math']]
# Out:
#    math
# 0    50
# 1    60
# 2    45
# 3    30
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['math'].plot(kind='hist', bins=20, title='math')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='index', y='math', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['math']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('math')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['math'].plot(kind='line', figsize=(8, 4), title='math')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
exam.query('nclass == 1')[['math', 'english']]
# Out:
#    math  english
# 0    50       98
# 1    60       97
# 2    45       86
# 3    30       98

# %%
exam.query('math >= 50')[['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam[exam.math >= 50][['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam[exam.math >= 50][['id', 'math']].head(5)
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
exam.query('math >= 50') \
          [['id', 'math']] \
          .head(5)
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %% [markdown]
# ## 정렬

# %%
exam.sort_values('math', ascending=False)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 0    1       1    50       98       50
# 5    6       2    50       89       98
# 9   10       3    50       98       45
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values('math', ascending=False).head(5)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58

# %%
exam.sort_values('math', ascending=False).head(7)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 10  11       3    65       65       65

# %%
exam.sort_values(['nclass', 'math']).head(5) # 오름차순
# Out:
#    id  nclass  math  english  science
# 3   4       1    30       98       58
# 2   3       1    45       86       78
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 4   5       2    25       80       65

# %%
exam.sort_values(['nclass', 'math'], ascending=False ).head()
# Out:
#     id  nclass  math  english  science
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98
# 14  15       4    75       56       78

# %%
exam.sort_values(['nclass', 'math'], ascending=[True, False] ).head()
# Out:
#    id  nclass  math  english  science
# 1   2       1    60       97       60
# 0   1       1    50       98       50
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 7   8       2    90       78       25

# %%
exam.sort_index(ascending=True).head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.sort_index(ascending=False).head() # == exam.sort_values(by=['id'], ascending=False).head()
# Out:
#     id  nclass  math  english  science
# 19  20       5    78       83       58
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 16  17       5    65       68       98
# 15  16       4    58       98       65

# %%
exam.sort_values(by=['id'], ascending=False).head()
# Out:
#     id  nclass  math  english  science
# 19  20       5    78       83       58
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 16  17       5    65       68       98
# 15  16       4    58       98       65

# %% [markdown]
# ### 종료
